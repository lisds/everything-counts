# %% [markdown]
# # NOTEBOOK MARKDOWN TUTORIAL
#
# This notebook provides a variety of demonstrations for using Markdown in Jupyter Notebooks, including formatting text, creating tables, displaying mathematical formulas, and inserting images.

# %% [markdown]
# ## Table of Contents
# - [Working with Images](#img)
# - [Plotting Prep](#pp)
# - [Plotting Sine Function](#sine)
# - [Working with Markdown](#md)

# %% [markdown]
# ## Working with Images <a id='img'></a>

# %% [markdown]
# ### Option 1: Linking an Image
#
# How to **_LINK_** an image, resize, and align within a **markdown** cell (suppose the name of the image file is "Piazza_del_Campo_view_from_the_top.jpg" in the same directory as in this Jupyter notebook):
# ```HTML
# <img src="./Piazza_del_Campo_view_from_the_top.jpg" width=400 align="left"/>
# ```

# %% [markdown]
# <img src="Piazza_del_Campo_view_from_the_top.jpg" width=400 align="left"/>

# %% [markdown]
# ## Prep for Plotting <a id='pp'></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'

plt.style.use("seaborn-v0_8")

# %% [markdown]
# ## How to Plot the Sine Function <a id='sine'></a>

# %%
x = np.arange(0, 4*np.pi, 0.1)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)
plt.title('sine of x')
plt.show()

# %% [markdown]
# ## Working with Markdown Commands <a id='md'></a>

# %% [markdown]
# ### Header 3
# #### Header 4

# %% [markdown]
# > This is a block quote.

# %% [markdown]
# This is a line break:
#
# ---

# %% [markdown]
# This is code section example:
# ```Python
# a = 23
# b = 15
# print(a+b)
# ```

# %% [markdown]
# Here is a line break <br>
# that looks nice.

# %% [markdown]
# Emphasis: Everybody likes `machine learning`.

# %% [markdown]
# This is _italic_.

# %% [markdown]
# This is **bold**.

# %% [markdown]
# This is **_bold and italic_**.

# %% [markdown]
# Here is an unordered list using "-" prefix for each list item:
# - Item 1
# - Item 2
# - Item 3

# %% [markdown]
# Here is an unordered list with a highlighed sub-list:
# - Item 1
# > - Item 1.a
# > - Item 1.b
# - Item 2
# - Item 3

# %% [markdown]
# Here is an ordered list - pay attention that we use the prefix "1." for each list item so that the actual numbering is done automatically for us upon running this markdown cell:
# 1. Item 1
# 1. Item 2
# 1. Item 3

# %% [markdown]
# Here is an ordered list with sublists using tabs:
# 1. Item 1
#     - Item 1A
#     - Item 1B
#         1. Item 1B.1
#         1. Item 1B.2
#     - Item 1C
#     - Item 1D
# 1. Item 2
# 1. Item 3

# %% [markdown]
# How to create a table:
#
# **Raw code:**
# ```HTML
# |Course Name | Code | Level|
# |---|---|---|
# |Machine Learning | 2319 | PG |
# |Intro to Analytics | 2350 | UG |
# ```
#
# **Upon running the cell:**
#
# |Course Name | Code | Level|
# |---|---|---|
# |Machine Learning | 2319 | PG |
# |Intro to Analytics | 2350 | UG |

# %% [markdown]
# This is a famous formula as a Latex example: $E=mc^2$

# %% [markdown]
# Here is a centered math formula: $$\sum_i^{j+k} x^3= \frac{\alpha}{\beta}$$

# %% [markdown]
# External webpage links: Our uni website is [here](http://www.rmit.edu.au).

# %% [markdown]
# ---
